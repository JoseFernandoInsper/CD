# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from numpy import arange
import os
import numpy as np

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\Jose Fernando\Documents\2° Semestre\Ciência dos Dados

# %%
dados = pd.read_excel('PNAD 2013 A.xlsx')

# %%
dados.head()
# Out:
#    V0101  UF  V0102  V0103  V0301  V0302  V8005  V0404  V4011  V0412  ...    \
# 1   2013  11     15      3      1      4     42      2    5.0      2  ...
# 2   2013  11     15      4      1      4     64      8    7.0      2  ...
# 3   2013  11     15      4      2      4     13      4    0.0      2  ...
# 4   2013  11     15      5      1      2     23      8    0.0      2  ...
# 5   2013  11     15      5      2      4     19      8    0.0      2  ...
#
#    V4706  V4707  V4809  V4810  V4711  V4718  V4720  V4742  V4750  V4729
# 1    NaN    NaN    NaN    NaN    NaN    NaN  350.0  350.0  350.0    244
# 2    NaN    NaN    NaN    NaN    NaN    NaN  678.0  339.0  339.0    243
# 3    NaN    NaN    NaN    NaN    NaN    NaN    0.0  339.0  339.0    243
# 4    1.0    3.0    5.0    5.0    1.0  800.0  800.0  266.0  266.0    243
# 5    NaN    NaN    NaN    NaN    NaN    NaN    0.0  266.0  266.0    243
#
# [5 rows x 72 columns]

# %%
dados.describe()
# Out:
# C:\Users\Jose Fernando\Anaconda3\lib\site-packages\numpy\lib\function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#           V0101             UF          V0102          V0103          V0301  \
# count  362555.0  362555.000000  362555.000000  362555.000000  362555.000000
# mean     2013.0      31.141868    2694.543802       8.881025       2.449910
# std         0.0      11.127250    2422.695268       5.435367       1.503639
# min      2013.0      11.000000      10.000000       1.000000       1.000000
# 25%      2013.0      23.000000     832.000000       5.000000       1.000000
# 50%      2013.0      31.000000    1954.000000       9.000000       2.000000
# 75%      2013.0      41.000000    4118.000000      13.000000       3.000000
# max      2013.0      53.000000   73146.000000      71.000000      24.000000
#
#                V0302          V8005          V0404          V4011  \
# count  362555.000000  362555.000000  362555.000000  217587.000000
# mean        3.028550      33.049813       5.053501       0.926112
# std         0.999594      20.870874       2.893868       2.122382
# min         2.000000       0.000000       0.000000       0.000000
# 25%         2.000000      16.000000       2.000000            NaN
# 50%         4.000000      31.000000       4.000000            NaN
# 75%         4.000000      48.000000       8.000000            NaN
# max         4.000000     109.000000       9.000000       7.000000
#
#                V0412      ...                V4706          V4707  \
# count  362555.000000      ...        172330.000000  172330.000000
# mean        3.210669      ...             4.729885       3.089909
# std         1.102632      ...             3.779515       1.065145
# min         2.000000      ...             1.000000       1.000000
# 25%         2.000000      ...                  NaN            NaN
# 50%         4.000000      ...                  NaN            NaN
# 75%         4.000000      ...                  NaN            NaN
# max         9.000000      ...            13.000000       5.000000
#
#                V4809          V4810          V4711         V4718  \
# count  172330.000000  172330.000000  172330.000000  1.723300e+05
# mean        6.018354       5.426612       1.397847  3.157315e+10
# std         3.411632       2.195770       0.489455  1.748613e+11
# min         1.000000       1.000000       1.000000  0.000000e+00
# 25%              NaN            NaN            NaN           NaN
# 50%              NaN            NaN            NaN           NaN
# 75%              NaN            NaN            NaN           NaN
# max        13.000000      10.000000       2.000000  1.000000e+12
#
#               V4720         V4742         V4750          V4729
# count  3.105190e+05  3.617780e+05  3.618360e+05  362555.000000
# mean   2.291647e+10  5.128560e+10  4.899181e+10     555.686955
# std    1.496375e+11  2.205800e+11  2.158512e+11     264.176203
# min    0.000000e+00  0.000000e+00  0.000000e+00     174.000000
# 25%             NaN           NaN           NaN     320.000000
# 50%             NaN           NaN           NaN     570.000000
# 75%             NaN           NaN           NaN     726.000000
# max    1.000000e+12  1.000000e+12  1.000000e+12    1150.000000
#
# [8 rows x 72 columns]

# %%
dados.V4803.describe()
# Out:
# count    362555.000000
# mean          7.600745
# std           4.877807
# min           1.000000
# 25%           3.000000
# 50%           8.000000
# 75%          12.000000
# max          17.000000
# Name: V4803, dtype: float64

# %%
d = pd.DataFrame()
d["sexo"] = dados.V0302.astype('category')
d["cor_ou_raca"] = dados.V0404.astype('category')
d["rede_de_ensino"] = dados.V6002.astype('category')
d["nivel_de_ensino"] = dados.V4802.astype('category')
d["Regiao"] = dados.UF
d["anos_de_estudos"] = dados.V4803.astype('category')
d["area_da_rede_publica_de_ensino"] = dados.V6020.astype('category')
#d[""] = dados..astype('float')

# %%
n = dados.shape[0]
d.sexo.cat.categories = ('feminino','masculino')
print('Frequências relativas por Sexo:')
ut1 = (d.sexo.value_counts()/n*100).round(decimals=1)
print(ut1,'\n')
plot = ut1.plot(kind='pie',title='sexo',autopct='%.1f',figsize=(6, 6))
# Out:
# Frequências relativas por Sexo:
# feminino     9.5
# masculino    9.3
# Name: sexo, dtype: float64

# %%
d.cor_ou_raca.cat.categories = ('indigena','branca','preta','amarela','parda','sem declaração')
print('Frequências relativas por cor:')
ut2 = (d.cor_ou_raca.value_counts()/n*100).round(decimals=1)
print(ut2,'\n')
plot = ut2.plot(kind='bar',title='Cor ou Raça',figsize=(6, 6),color=('b','w','k','r','y'))
# Out:
# Frequências relativas por cor:
# parda             10.7
# branca             6.5
# preta              1.4
# indigena           0.1
# amarela            0.0
# sem declaração     0.0
# Name: cor_ou_raca, dtype: float64

# %%
d.rede_de_ensino.cat.categories = ('publica','privada')
print('Frequências relativas por rede de ensino:')
ut3 = (d.rede_de_ensino.value_counts()/n*100).round(decimals=1)
print(ut3,'\n')
plot = ut3.plot(kind='bar',title='rede de ensino',figsize=(6, 6),color=('b','w','k','r','y'))
# Out:
# Frequências relativas por rede de ensino:
# publica    18.8
# privada     0.0
# Name: rede_de_ensino, dtype: float64

# %%
d.nivel_de_ensino.cat.categories = ('maternal', 'classe de alfabetização', 'alfabetização de adultos', '1° a 4° serie/8', '5° a 8° serie/8', '1° serie/9', '2° a 5° serie/9', '6° a 9° serie/9', 'E.J.A. E.F.', 'ensino medio e pre-vest', 'superior')
print('Frequências relativas por nivel de ensino:')
ut4 = (d.nivel_de_ensino.value_counts()/n*100).round(decimals=1)
print(ut4,'\n')
plot = ut4.plot(kind='bar',title='nivel de ensino',figsize=(6, 6),color=('b','w','k','r','y'))
# Out:
# Frequências relativas por nivel de ensino:
# 2° a 5° serie/9             5.6
# 6° a 9° serie/9             5.1
# ensino medio e pre-vest     3.8
# 1° serie/9                  1.2
# maternal                    1.2
# superior                    0.7
# 5° a 8° serie/8             0.5
# 1° a 4° serie/8             0.3
# classe de alfabetização     0.2
# E.J.A. E.F.                 0.1
# alfabetização de adultos    0.1
# Name: nivel_de_ensino, dtype: float64

# %%
d.Regiao[(dados.UF >= 10) & (dados.UF < 20)] = 1
d.Regiao[(dados.UF >= 20) & (dados.UF < 30)] = 2
d.Regiao[(dados.UF >= 30) & (dados.UF < 40)] = 3
d.Regiao[(dados.UF >= 40) & (dados.UF < 50)] = 4
d.Regiao[(dados.UF >= 50) & (dados.UF < 60)] = 5

d.Regiao = d.Regiao.astype('category')
d.Regiao.cat.categories = ('Norte', 'Nordeste', 'Sudeste', 'Sul', 'Centro-Oeste')

ut5 = d.Regiao.value_counts().round(decimals=1)
print(ut5,'\n')

plot = ut5.plot(kind='bar',title='Regiao',figsize=(6, 6),color=('b','g','k','r','m','c','y'))
plt.ylabel('Freq.Relativa (em%)')
plt.xlabel('Regiões')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-1f0839b3864d> in <module>()
# ----> 1 d.Regiao[(dados.UF >= 10) & (dados.UF < 20)] = 1
#       2 d.Regiao[(dados.UF >= 20) & (dados.UF < 30)] = 2
#       3 d.Regiao[(dados.UF >= 30) & (dados.UF < 40)] = 3
#       4 d.Regiao[(dados.UF >= 40) & (dados.UF < 50)] = 4
#       5 d.Regiao[(dados.UF >= 50) & (dados.UF < 60)] = 5
#
# C:\Users\Jose Fernando\Anaconda3\lib\site-packages\pandas\core\series.py in __setitem__(self, key, value)
#     751         # do the setitem
#     752         cacher_needs_updating = self._check_is_chained_assignment_possible()
# --> 753         setitem(key, value)
#     754         if cacher_needs_updating:
#     755             self._maybe_update_cacher()
#
# C:\Users\Jose Fernando\Anaconda3\lib\site-packages\pandas\core\series.py in setitem(key, value)
#     742                 key = check_bool_indexer(self.index, key)
#     743                 try:
# --> 744                     self.where(~key, value, inplace=True)
#     745                     return
#     746                 except InvalidIndexError:
#
# C:\Users\Jose Fernando\Anaconda3\lib\site-packages\pandas\core\generic.py in where(self, cond, other, inplace, axis, level, try_cast, raise_on_error)
#    4482             new_data = self._data.putmask(mask=cond, new=other, align=align,
#    4483                                           inplace=True, axis=block_axis,
# -> 4484                                           transpose=self._AXIS_REVERSED)
#    4485             self._update_inplace(new_data)
#    4486
#
# C:\Users\Jose Fernando\Anaconda3\lib\site-packages\pandas\core\internals.py in putmask(self, **kwargs)
#    2918
#    2919     def putmask(self, **kwargs):
# -> 2920         return self.apply('putmask', **kwargs)
#    2921
#    2922     def diff(self, **kwargs):
#
# C:\Users\Jose Fernando\Anaconda3\lib\site-packages\pandas\core\internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, raw, **kwargs)
#    2888
#    2889             kwargs['mgr'] = self
# -> 2890             applied = getattr(b, f)(**kwargs)
#    2891             result_blocks = _extend_blocks(applied, result_blocks)
#    2892
#
# C:\Users\Jose Fernando\Anaconda3\lib\site-packages\pandas\core\internals.py in putmask(self, mask, new, align, inplace, axis, transpose, mgr)
#    1379         if isinstance(new, np.ndarray) and len(new) == len(mask):
#    1380             new = new[mask]
# -> 1381         new_values[mask] = new
#    1382         new_values = self._try_coerce_result(new_values)
#    1383         return [self.make_block(values=new_values)]
#
# C:\Users\Jose Fernando\Anaconda3\lib\site-packages\pandas\core\categorical.py in __setitem__(self, key, value)
#    1609         # something to np.nan
#    1610         if len(to_add) and not isnull(to_add).all():
# -> 1611             raise ValueError("Cannot setitem on a Categorical with a new "
#    1612                              "category, set the categories first")
#    1613
#
# ValueError: Cannot setitem on a Categorical with a new category, set the categories first

# %%
d.anos_de_estudos.cat.categories = ('sem instrução menos de 1 ano','1 ano', '2 anos', '3 anos', '4 anos','5 anos','6 anos',
                                  '7 anos','8 anos','9 anos','10 anos','11 anos','12 anos','13 anos','14 anos','15 anos ou mais','nao determinados')
print('Frequências relativas de anos de estudos:')
ut6 = (d.anos_de_estudos.value_counts()/n*100).round(decimals=1)
print(ut6,'\n')
plot = ut6.plot(kind='bar',title='anos de estudos',figsize=(6, 6),color=('b','w','k','r','y'))
# Out:
# Frequências relativas de anos de estudos:
# sem instrução menos de 1 ano    4.0
# 4 anos                          1.6
# 3 anos                          1.6
# 5 anos                          1.5
# 2 anos                          1.5
# 1 ano                           1.5
# 8 anos                          1.3
# 6 anos                          1.3
# 9 anos                          1.2
# 7 anos                          1.2
# 10 anos                         1.1
# nao determinados                0.2
# 11 anos                         0.2
# 12 anos                         0.2
# 13 anos                         0.1
# 14 anos                         0.1
# 15 anos ou mais                 0.1
# Name: anos_de_estudos, dtype: float64

# %%
d.area_da_rede_publica_de_ensino.cat.categories = ('municipal','estadual','federal')
print('Frequências relativas por area da rede publica de ensino:')
ut7 = (d.area_da_rede_publica_de_ensino.value_counts()/n*100).round(decimals=1)
print(ut7,'\n')
plot = ut7.plot(kind='bar',title='rede publica',figsize=(6, 6),color=('b','w','k','r','y'))
# Out:
# Frequências relativas por area da rede publica de ensino:
# municipal    9.9
# estadual     8.3
# federal      0.6
# Name: area_da_rede_publica_de_ensino, dtype: float64

# %%
ct = pd.crosstab(d.nivel_de_ensino, d.rede_de_ensino)
print(ct)
# Out:
# rede_de_ensino            publica  privada
# nivel_de_ensino
# maternal                     4202        0
# classe de alfabetização       733        0
# alfabetização de adultos      382        0
# 1° a 4° serie/8               938        0
# 5° a 8° serie/8              1878        0
# 1° serie/9                   4395        0
# 2° a 5° serie/9             20375        0
# 6° a 9° serie/9             18583        0
# E.J.A. E.F.                   427        0
# ensino medio e pre-vest     13780        0
# superior                     2488        0

# %%
ct2 = pd.crosstab(d.cor_ou_raca, d.anos_de_estudos)
print(ct2)
plot = ct2.plot(kind='bar',title='cor vs anos de estudos',figsize=(6, 6),color=('b','w','k','r','y'))
# Out:
# anos_de_estudos  sem instrução menos de 1 ano  1 ano  2 anos  3 anos  4 anos  \
# cor_ou_raca
# indigena                                  136     45      50      53      42
# branca                                   5064   1727    1806    1842    1947
# preta                                     927    350     408     448     434
# amarela                                    24     12      15      13       7
# parda                                    8361   3153    3186    3405    3540
# sem declaração                              0      0       0       0       0
#
# anos_de_estudos  5 anos  6 anos  7 anos  8 anos  9 anos  10 anos  11 anos  \
# cor_ou_raca
# indigena             32      20      32      24      11       20        6
# branca             1823    1594    1465    1692    1621     1475      339
# preta               428     357     373     385     375      305       54
# amarela              14      13      10      17       5       19        1
# parda              3174    2661    2495    2773    2386     2144      352
# sem declaração        0       0       0       0       0        0        0
#
# anos_de_estudos  12 anos  13 anos  14 anos  15 anos ou mais  nao determinados
# cor_ou_raca
# indigena               3        1        2                3                 5
# branca               277      259      218              172               238
# preta                 37       31       42               24                70
# amarela                9        4        4                4                 5
# parda                262      237      212              115               457
# sem declaração         0        0        0                0                 0

# %%
ct3 = pd.crosstab(d.nivel_de_ensino, d.Regiao)
print(ct3)
plot = ct3.plot(kind='bar',title='regiao vs nivel de ensino',figsize=(6, 6),color=('b','w','k','r','y'))
# Out:
# Regiao                    Norte  Nordeste  Sudeste   Sul  Centro-Oeste
# nivel_de_ensino
# maternal                    874      1312     1117   511           388
# classe de alfabetização     190       225      177    55            86
# alfabetização de adultos     39       208       73    40            22
# 1° a 4° serie/8             272       310      151   145            60
# 5° a 8° serie/8             421       409      352   612            84
# 1° serie/9                  971      1220     1152   602           450
# 2° a 5° serie/9            4807      6148     4830  2688          1902
# 6° a 9° serie/9            3847      5977     4748  2170          1841
# E.J.A. E.F.                 120       171       49    55            32
# ensino medio e pre-vest    2824      4137     3607  1862          1350
# superior                    541       830      479   370           268

# %%
ct4 = pd.crosstab(d.nivel_de_ensino, d.sexo)
print(ct4)
plot = ct4.plot(kind='bar',title='nivel vs M F',figsize=(6, 6),color=('b','w','k','r','y'))
# Out:
# sexo                      feminino  masculino
# nivel_de_ensino
# maternal                      2167       2035
# classe de alfabetização        354        379
# alfabetização de adultos       145        237
# 1° a 4° serie/8                427        511
# 5° a 8° serie/8                975        903
# 1° serie/9                    2292       2103
# 2° a 5° serie/9              10842       9533
# 6° a 9° serie/9               9635       8948
# E.J.A. E.F.                    178        249
# ensino medio e pre-vest       6286       7494
# superior                      1092       1396

# %%
ct5 = pd.crosstab(d.anos_de_estudos, d.Regiao)
print(ct5)
plot = ct5.plot(kind='bar',title='anos de estudo vs regiao',figsize=(6, 6),color=('b','w','k','r','y'))
# Out:
# Regiao                        Norte  Nordeste  Sudeste   Sul  Centro-Oeste
# anos_de_estudos
# sem instrução menos de 1 ano   3193      4416     3638  1856          1409
# 1 ano                          1282      1592     1214   717           482
# 2 anos                         1312      1642     1281   731           499
# 3 anos                         1366      1773     1367   737           518
# 4 anos                         1287      2017     1390   746           530
# 5 anos                         1111      1654     1390   796           520
# 6 anos                          951      1385     1206   661           442
# 7 anos                          919      1330     1114   579           433
# 8 anos                          962      1463     1326   640           500
# 9 anos                          915      1339     1145   575           424
# 10 anos                         840      1173     1023   545           382
# 11 anos                         151       230      174   117            80
# 12 anos                         127       202      109    86            64
# 13 anos                         108       176      111    70            67
# 14 anos                         118       167       74    77            42
# 15 anos ou mais                  72       105       60    54            27
# nao determinados                192       283      113   123            64

# %% [markdown]
# ##conclusão##
#
# Analizando os graficos e os dados chegamos a conclusão que será mais recomendado para senhor gold se estabelecer nas regiões nordeste ou sudeste do brasil, onde a maior numero de jovens com nivel de ensino medio e pre-vestibulando. de acordo com os graficos é melhor na regiao nordeste.

# %%
d["salario"] = dados.V4742[(dados.V4742 < 2000)&(dados.V4742 > 0)]
d = d.dropna()
d.salario = d.salario.astype('float')

# %%
d["anos_de_estudo"] = dados.V4803[(dados.V4803 < 16) & (dados.V4803 > 1)]
d.anos_de_estudo = d.anos_de_estudo.astype('float')

# %%
d.salario.head()
# Out:
# 3     339.0
# 20    280.0
# 21    280.0
# 25    333.0
# 28    650.0
# Name: salario, dtype: float64

# %%
faixa = arange(0,10000, 200)
plot = d.salario.plot.hist(bins=faixa,normed=1)
plt.xlim(0, 5000)
#plt.ylim(0, 50)
# Out:
# (0, 5000)

# %%
ufa = pd.crosstab(d.salario,d.Regiao)
plot = ufa.plot.box()

# %%
d.boxplot(column = "salario", by = "Regiao")

# %%
ct5 = pd.crosstab(d.anos_de_estudo, d.sexo)
plot = ct5.plot(kind='bar',title='anos de estudo vs sexo',figsize=(6, 6),color=('b','w','k','r','y'))

# %%
d.boxplot(column = "anos_de_estudo", by = "sexo")

# %% [markdown]
# Diferente da minha primeira conclusão, agora a regiao mais apta a se intalar a instituição de ensino é a regiao sudeste poe seu alto nivel salarial em relação ao nordeste. implicando em ganhar mais dinheiro nas mensalidades.
# para : Sr Gold
